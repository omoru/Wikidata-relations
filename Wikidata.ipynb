# %% [markdown]
# #Relación entre entidades en Wikidata

# %%
# %pip install qwikidata
# Out:
# Collecting qwikidata
#   Downloading qwikidata-0.4.0-py3-none-any.whl (20 kB)
# Collecting mypy-extensions
#   Downloading mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from qwikidata) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->qwikidata) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->qwikidata) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->qwikidata) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->qwikidata) (2021.10.8)
# Installing collected packages: mypy-extensions, qwikidata
# Successfully installed mypy-extensions-0.4.3 qwikidata-0.4.0

# %%
from qwikidata.entity import WikidataItem, WikidataProperty, WikidataLexeme 
from qwikidata.linked_data_interface import get_entity_dict_from_api
import time

# %% [markdown]
# **En primer lugar obtenemos la información de las entidades que se usarán en esta práctica y las almacenamos en variables para no tener que estar pidiendo una y otra vez las mismas entidades a Wikidata.**

# %%
piano = 'Q5994'
piano_dict= get_entity_dict_from_api(piano)
q5994 = WikidataItem(piano_dict)
electronic_keyboard = 'Q1343007'
electronic_keyboard_dict= get_entity_dict_from_api(electronic_keyboard)
q1343007 = WikidataItem(electronic_keyboard_dict)

# %%
String_synthesizer = 'Q2355465'
Hans_Zimmer = 'Q76364'
String_synthesizer_dict = get_entity_dict_from_api(String_synthesizer)
Hans_Zimmer_dict = get_entity_dict_from_api(Hans_Zimmer)
q2355465 =  WikidataItem(String_synthesizer_dict)
q76364 = WikidataItem(Hans_Zimmer_dict)

# %%
Pirates_of_the_Caribbean= 'Q46717'
Pirates_of_the_Caribbean_dict = get_entity_dict_from_api(Pirates_of_the_Caribbean)
q46717 = WikidataItem(Pirates_of_the_Caribbean_dict)

# %%
The_Lion_king = 'Q36479'
The_Lion_king_dict = get_entity_dict_from_api(The_Lion_king)
q36479 =  WikidataItem(The_Lion_king_dict)

# %%
Toy_story ='Q171048'
Toy_story_dict = get_entity_dict_from_api(Toy_story)
q171048 = WikidataItem(Toy_story_dict)

# %%
Iron_man = 'Q192724'
Iron_man_dict= get_entity_dict_from_api(Iron_man)
q192724 = WikidataItem(Iron_man_dict)

# %% [markdown]
# **Creamos un array de tuplas, y cada una de estas tiene el nombre de las propiedades y su identificador en Wikidata.**

# %%
properties=[('instance of','P31'),('subclass of','P279'),('has part','P527'),('instrument','P1303'),('genre','P136')]

# %% [markdown]
# **Declaramos dos clases: Node y Tree.**
# Un nodo puede ser o propiedad o entidad, y el árbol le construiré de tal manera que vayan intercalandose por niveles; es decir, el nivel 0 será una entidad, el nivel 1 tendrán todas las propiedades que se pueden aplicar al padre del nivel 0; el nivel 2 serán todas las entidades que conseguimos al aplicar las propiedades del nivel 1 a la entidad del nivel 0, y asi continuamente.
#
# Así, si lo recorremos en profundidad vamos obteniendo cada camino con la longitud maxima(5 en este caso, por lo que el camino sería en verdad de longitud 10 ya que como hemos dicho, de esos 10 niveles 5 son propiedades y 5 son entidades

# %%
class Node:
    def __init__(self, data, tipo, childs = None):
        #print ("Node __init__: " + str(data))
        self.data = data
        self.type = tipo
        self.childs = list()
    def __str__(self):
        if self.type == "property":
            return 'property : ' + str(self.data)
        return 'Entity : ' + str(self.data.get_label())
    
    def _isLeaf(self):
        return len(self.childs) == 0

    def _add(self, new_node):
        # print ("Node _add: " + str(new_node.data) + ' to ' + str(self.data))
        self.childs.append(new_node)

    # print preorder traversal		
    def _preorder(self):
        print (self) 
        for child in self.childs:
            child._preorder()

# %%
class Tree:
    def __init__(self,node):
        self.root = node

    def preorder(self):
        print ('----Preorder----')
        self.root._preorder()

# %% [markdown]
# Construimos el árbol como había explicado anteriormente.

# %%
def get_claims(nodo,profundidad):
    if nodo == None or (profundidad > 4):
        return
    for pr in properties:
        property_node = Node(pr[1],"property")
        claim_group = nodo.data.get_truthy_claim_group(pr[1])
        if len(claim_group) > 0:
            nodo._add(property_node)
            for g in claim_group:
                if g.mainsnak.value_datatype == "wikibase-entityid":
                    entity = g.mainsnak.datavalue.value['id']
                    q_dict = get_entity_dict_from_api(entity)
                    q = WikidataItem(q_dict)
                    entity_node =Node(q,"entidad")
                    property_node._add(entity_node)
                    get_claims(entity_node,profundidad + 1)

# %% [markdown]
# **La siguiente celda de código se encarga de construir un árbol por cada entidad que hemos guardado al principio.La raiz de estos árboles es cada una de las entidades mencionadas.Guardaremos estos arboles en la lista global "list_of_trees"**
#
# La ejecución de la celda puede llevar varios minutos ya que los posibles caminos de longitud 5 son abundantes.

# %%
start = time.time()
list_of_trees = list()

tree1 = Tree(Node(q5994,"entidad")) #piano
tree2 = Tree(Node(q1343007,"entidad")) #electronic keyboard
tree3 = Tree(Node(q2355465,"entidad")) #String sintetizer
tree4 = Tree(Node(q76364,"entidad"))#hans Zimmer
tree5 =  Tree(Node(q46717,"entidad"))#Pirates of the Caribbean: The Curse of the Black Pearl
tree6 =  Tree(Node(q36479,"entidad"))#The Lion King
tree7 =  Tree(Node(q171048,"entidad"))#Toy Story
tree8 =  Tree(Node(q192724,"entidad"))#Iron Man

get_claims(tree1.root,0)
get_claims(tree2.root,0)
get_claims(tree3.root,0)
get_claims(tree4.root,0)
get_claims(tree5.root,0)
get_claims(tree6.root,0)
get_claims(tree7.root,0)
get_claims(tree8.root,0)

list_of_trees.append(tree1)
list_of_trees.append(tree2)
list_of_trees.append(tree3)
list_of_trees.append(tree4)
list_of_trees.append(tree5)
list_of_trees.append(tree6)
list_of_trees.append(tree7)
list_of_trees.append(tree8)

print(time.time()-start,"seconds")
# Out:
# 597.8447694778442 seconds

# %% [markdown]
# **A continuación definiremos algunas funciones auxiliares:**

# %%
"""
Recibe una interseccion ( tupla que contiene informacion sobre la intersección) y las lista de intersecciones en la
que iremos almacenando estas.
Recorre las tuplas de la lista de intersecciones buscando si ya existe una interseccion con la misma entidad.
    -Si no existe la añadimos a la lista de intersecciones
    -Si existe y la distancia de la nueva intersección es menor entonces la sustituimos.

"""
def insertarInterseccion(interseccion,lista_intersecciones):
    encontrado = False
    i=0
    max_len = len(lista_intersecciones)
    while i < max_len:
        #si existe una interseccion con esa entidad mirar si esta a menor distancia
        j = 0
        long =len(lista_intersecciones[i]) 
        while not(encontrado) and j < long:
            if lista_intersecciones[i][j][0] == interseccion[0]:
                if(interseccion[1] < lista_intersecciones[i][j][1]):
                    lista_intersecciones[i].clear()
                    lista_intersecciones[i].append(list(interseccion))
                encontrado = True
            j+=1 
            
        if encontrado:
            return
        
        i+=1
    
    #si no la encuentra la añade
    aux = list()
    aux.append(interseccion)
    lista_intersecciones.append(aux)

# %%
"""

Esta función se encarga de buscar un nodo en un arbol(pasaremos por parametro el nodo raiz de este), y en caso de
encontrarlo(es decir que existe una intersección), la añadiremos a nuestra lista de intersecciones con la ayuda de la
función anterior.

Las intersecciones serán tuplas que contienen respectivamente :
    -Nombre de la entidad en la que intersectan los caminos
    -Distancia de la relacion(suma de las distancias de la entidad inicial a la de interseccion)
    -Distancia de la entidad inicial a la de intersección del camino del arbol del que seleccionamos los nodos a buscar
    -Distancia de la entidad inicial a la de intersección del camino del arbol que usamos como árbol de búsqueda
    -Camino del primer árbol
    -Camino del segundo árbol
Así tendremos toda la información necesaria de las intersecciones almacenadas

-Parametros:
    -nodo_a_buscar: entidad que estamos buscando en el árbol de busqueda
    -nodo: iremos modificando este parametro de forma que nos sirve para recorrer el árbol de búsqueda
    -profundidad_nodo_buscar
    -profundidad_nodo
    -camino_actual: camino actual hasta el nodo_a_buscar
    -lista_intersecciones
    -camino_busqueda: camino actual hasta el nodo del árbol de búsqueda
    
"""

def getCaminos(nodo_a_buscar,nodo,profundidad_nodo_buscar,profundidad_nodo,camino_actual,lista_intersecciones,camino_busqueda):
    if nodo.type =="entidad" and nodo.data.get_label() == nodo_a_buscar.data.get_label():
        camino_actual.append(nodo)
        camino = list(camino_actual)
        camino_busq = list(camino_busqueda)
        interseccion = (nodo_a_buscar.data.get_label(),int(profundidad_nodo_buscar/2 + profundidad_nodo/2),
                        int(profundidad_nodo_buscar/2),int(profundidad_nodo/2),camino,camino_busq)
        insertarInterseccion(interseccion,lista_intersecciones)
        camino_actual.pop()
        return
        
    elif nodo._isLeaf():
        return
    
    camino_actual.append(nodo)
    for child in nodo.childs:
        getCaminos(nodo_a_buscar,child,profundidad_nodo_buscar,profundidad_nodo + 1,camino_actual,lista_intersecciones,camino_busqueda)
    camino_actual.pop()

# %%
"""
Esta función se encarga de recorrer un árbol e ir entidad por entidad(nodo_a_buscar) buscándola en otro árbol(nodo_arbol_busqueda)
Así,con la ayuda de la función anterior podemos ir nodo por nodo de un árbol buscando si existen intersecciones con 
otro árbol.

-Parámetros:
    -nodo_a_buscar: entidad que buscaremos en el árbol de busqueda. Este puntero se usara para que busquemos todas las
        entidades del árbol.
    -profundidad_nodo_buscar
    -nodo_arbol_busqueda: raiz del árbol de búsqueda
    -lista_intersecciones
    -camino_busqueda:camino actual hasta el nodo del árbol de búsqueda
    
"""
def getRelationsAux(nodo_a_buscar,profundidad_nodo_buscar,nodo_arbol_busqueda,lista_intersecciones,camino_busqueda):
    
    if nodo_a_buscar.type == "entidad":
        camino_actual = list()
        #buscamos intersecciones de esta entidad con el árbol de búsqueda
        getCaminos(nodo_a_buscar,nodo_arbol_busqueda,profundidad_nodo_buscar,0,
                   camino_actual,lista_intersecciones,camino_busqueda)
    
    if nodo_a_buscar._isLeaf():
        return
    
    for child in nodo_a_buscar.childs:
        camino_busqueda.append(child)
        getRelationsAux(child,profundidad_nodo_buscar + 1,nodo_arbol_busqueda,lista_intersecciones,camino_busqueda)
        camino_busqueda.pop()

# %%
#Recibe dos árboles y calcula la lista de intersecciones con ayuda de la función anterior
def getRelations(tree1,tree2):
    lista_intersecciones = list()
    camino_busqueda = list()
    camino_busqueda.append(tree1.root)
    getRelationsAux(tree1.root,0,tree2.root,lista_intersecciones,camino_busqueda)
    return lista_intersecciones

# %%
#Recibe un camino y lo muestra por pantalla
def caminoToString(camino):
    for nodo in camino:
        if(nodo.type == "property"):
            print(nodo.data +"---->")
        else :
            print(nodo.data.get_label()+ "-->")

# %%
#Recibe la lista de intersecciones y la muestra por pantalla
def caminosToString(lista_intersecciones):
    for interseccion in lista_intersecciones:
        for tupla in interseccion:
            print("INTERSECCION EN",tupla[0],"A DISTANCIA",tupla[1],"\n")
            print("==============================================\n")
            print("En C1 la interseccion está a distancia",tupla[3])
            caminoToString(tupla[4])
            print("\n")
            print("En C2 la interseccion está a distancia",tupla[2])
            caminoToString(tupla[5])
            print("\n")

# %%
#Recibe la lista de intersecciones y devuelve las entidades en común
def getEntidadesEnComun(lista_intersecciones):
    entidades = list()
    for interseccion in lista_intersecciones:
        for tupla in interseccion:
            entidades.append(tupla[0])
    return entidades

# %% [markdown]
# # Caminos mínimos y entidades comunes

# %% [markdown]
# Como veremos al calcular las entidades comunes dos a dos,estas tienen muchas entidades en común aunque sean muy genéricas como por ejemplo artificial physical object,product,tool,artificial entity,entity,second-order metaclass', 'third-order metaclass', 'fixed-order metaclass', 'variable-order metaclass', '(meta)class', 'Wikidata metaclass'...
# Son terminos que engloban demasiadas entidades.

# %% [markdown]
# - piano (Q5994), electronic keyboard (Q1343007),

# %%
comunes1 = getRelations(tree1,tree2)

# %%
len(comunes1)
# Out:
# 43

# %%
entidades = getEntidadesEnComun(comunes1)

# %%
print(entidades)
# Out:
# ['musical instrument', 'sound generator', 'device', 'equipment', 'artificial physical object', 'product', 'tool', 'converter', 'artificial entity', 'goods', 'entity', 'variable-order metaclass', 'concept', 'observer', 'catalyst', 'musical instrument part', 'work', 'part of', 'class of instruments', 'first-order metaclass', 'second-order metaclass', 'fixed-order metaclass', 'class', 'metaclass', 'keyboard instrument', 'third-order metaclass', '(meta)class', 'Wikidata metaclass', 'formal ontology concept', 'philosophical concept', 'abstract object', 'member of class (philosophy)', 'musical keyboard', 'keyboard', 'input device', 'peripheral equipment', 'user interface', 'receiver', 'input-output device', 'physical interface', 'push-button', 'switch', 'key']

# %%
caminosToString(comunes1)
# Out:
# INTERSECCION EN musical instrument A DISTANCIA 3
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
#
#
# En C2 la interseccion está a distancia 1
# piano-->
# P31---->
# musical instrument-->
#
#
# INTERSECCION EN sound generator A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# sound generator-->
#
#
# En C2 la interseccion está a distancia 2
# piano-->
# P31---->
# musical instrument-->
# P279---->
# sound generator-->
#
#
# INTERSECCION EN device A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# electronic keyboard-->
# P279---->
# electronic musical instrument-->
# P279---->
# electronic instrument-->
# P279---->
# device-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P31---->
# musical instrument-->
# P279---->
# sound generator-->
# P279---->
# device-->
#
#
# INTERSECCION EN equipment A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# equipment-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# equipment-->
#
#
# INTERSECCION EN artificial physical object A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# equipment-->
# P279---->
# artificial physical object-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# equipment-->
# P279---->
# artificial physical object-->
#
#
# INTERSECCION EN product A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# product-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# product-->
#
#
# INTERSECCION EN tool A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
#
#
# En C2 la interseccion está a distancia 2
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
#
#
# INTERSECCION EN converter A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
#
#
# INTERSECCION EN artificial entity A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P31---->
# work-->
# P279---->
# artificial entity-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P31---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P31---->
# work-->
# P279---->
# artificial entity-->
#
#
# INTERSECCION EN goods A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# product-->
# P279---->
# goods-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# product-->
# P279---->
# goods-->
#
#
# INTERSECCION EN entity A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
# P279---->
# entity-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
# P279---->
# entity-->
#
#
# INTERSECCION EN variable-order metaclass A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
# P31---->
# variable-order metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
# P279---->
# entity-->
# P31---->
# variable-order metaclass-->
#
#
# INTERSECCION EN concept A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P31---->
# metaclass-->
# P31---->
# concept-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
# P279---->
# entity-->
# P31---->
# concept-->
#
#
# INTERSECCION EN observer A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
# P527---->
# observer-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
# P527---->
# observer-->
#
#
# INTERSECCION EN catalyst A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
# P527---->
# catalyst-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
# P527---->
# catalyst-->
#
#
# INTERSECCION EN musical instrument part A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P527---->
# musical instrument part-->
#
#
# En C2 la interseccion está a distancia 2
# piano-->
# P31---->
# musical instrument-->
# P527---->
# musical instrument part-->
#
#
# INTERSECCION EN work A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P31---->
# work-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P31---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P31---->
# work-->
#
#
# INTERSECCION EN part of A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P279---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P279---->
# part of-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P31---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P279---->
# part of-->
#
#
# INTERSECCION EN class of instruments A DISTANCIA 4
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
#
#
# En C2 la interseccion está a distancia 2
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
#
#
# INTERSECCION EN first-order metaclass A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
#
#
# INTERSECCION EN second-order metaclass A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P31---->
# second-order metaclass-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P31---->
# second-order metaclass-->
#
#
# INTERSECCION EN fixed-order metaclass A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
#
#
# INTERSECCION EN class A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
#
#
# INTERSECCION EN metaclass A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P31---->
# metaclass-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P31---->
# metaclass-->
#
#
# INTERSECCION EN keyboard instrument A DISTANCIA 2
#
# ==============================================
#
# En C1 la interseccion está a distancia 1
# electronic keyboard-->
# P279---->
# keyboard instrument-->
#
#
# En C2 la interseccion está a distancia 1
# piano-->
# P279---->
# keyboard instrument-->
#
#
# INTERSECCION EN third-order metaclass A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P31---->
# second-order metaclass-->
# P31---->
# third-order metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P31---->
# second-order metaclass-->
# P31---->
# third-order metaclass-->
#
#
# INTERSECCION EN (meta)class A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
# P279---->
# (meta)class-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
# P279---->
# (meta)class-->
#
#
# INTERSECCION EN Wikidata metaclass A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
# P279---->
# Wikidata metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
# P279---->
# Wikidata metaclass-->
#
#
# INTERSECCION EN formal ontology concept A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P31---->
# metaclass-->
# P31---->
# formal ontology concept-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P31---->
# metaclass-->
# P31---->
# formal ontology concept-->
#
#
# INTERSECCION EN philosophical concept A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P31---->
# philosophical concept-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P31---->
# philosophical concept-->
#
#
# INTERSECCION EN abstract object A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P279---->
# abstract object-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P279---->
# abstract object-->
#
#
# INTERSECCION EN member of class (philosophy) A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P527---->
# member of class (philosophy)-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P527---->
# member of class (philosophy)-->
#
#
# INTERSECCION EN musical keyboard A DISTANCIA 4
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
#
#
# En C2 la interseccion está a distancia 2
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
#
#
# INTERSECCION EN keyboard A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
#
#
# INTERSECCION EN input device A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
#
#
# INTERSECCION EN peripheral equipment A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# peripheral equipment-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# peripheral equipment-->
#
#
# INTERSECCION EN user interface A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# user interface-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# user interface-->
#
#
# INTERSECCION EN receiver A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# receiver-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# receiver-->
#
#
# INTERSECCION EN input-output device A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# input-output device-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# input-output device-->
#
#
# INTERSECCION EN physical interface A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# physical interface-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P279---->
# input device-->
# P279---->
# physical interface-->
#
#
# INTERSECCION EN push-button A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P527---->
# push-button-->
#
#
# En C2 la interseccion está a distancia 4
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P527---->
# push-button-->
#
#
# INTERSECCION EN switch A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P527---->
# push-button-->
# P279---->
# switch-->
#
#
# En C2 la interseccion está a distancia 5
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P279---->
# keyboard-->
# P527---->
# push-button-->
# P279---->
# switch-->
#
#
# INTERSECCION EN key A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# electronic keyboard-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P527---->
# key-->
#
#
# En C2 la interseccion está a distancia 3
# piano-->
# P279---->
# keyboard instrument-->
# P527---->
# musical keyboard-->
# P527---->
# key-->

# %% [markdown]
# - String synthesizer (Q2355465), Hans Zimmer (Q76364)

# %%
comunes2 = getRelations(tree3,tree4)
len(comunes2)
# Out:
# 31

# %%
entidades2 = getEntidadesEnComun(comunes2)
print(entidades2)
# Out:
# ['electronic musical instrument', 'class of instruments', 'first-order metaclass', 'second-order metaclass', 'third-order metaclass', 'fixed-order metaclass', 'variable-order metaclass', '(meta)class', 'Wikidata metaclass', 'class', 'metaclass', 'concept', 'formal ontology concept', 'philosophical concept', 'abstract object', 'member of class (philosophy)', 'electrophone', 'musical instrument', 'sound generator', 'device', 'tool', 'equipment', 'converter', 'product', 'musical instrument part', 'work', 'part of', 'electrical apparatus', 'electrical load', 'electronic instrument', 'artificial physical object']

# %%
caminosToString(comunes2)
# Out:
# INTERSECCION EN electronic musical instrument A DISTANCIA 3
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Hans Zimmer-->
# P1303---->
# synthesizer-->
# P279---->
# electronic musical instrument-->
#
#
# En C2 la interseccion está a distancia 1
# String synthesizer-->
# P31---->
# electronic musical instrument-->
#
#
# INTERSECCION EN class of instruments A DISTANCIA 4
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Hans Zimmer-->
# P1303---->
# keyboard instrument-->
# P31---->
# class of instruments-->
#
#
# En C2 la interseccion está a distancia 2
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
#
#
# INTERSECCION EN first-order metaclass A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P1303---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
#
#
# En C2 la interseccion está a distancia 3
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
#
#
# INTERSECCION EN second-order metaclass A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P31---->
# human-->
# P31---->
# group of organisms known by one particular common name-->
# P31---->
# Wikidata metaclass-->
# P31---->
# second-order metaclass-->
#
#
# En C2 la interseccion está a distancia 4
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P31---->
# second-order metaclass-->
#
#
# INTERSECCION EN third-order metaclass A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# Hans Zimmer-->
# P31---->
# human-->
# P31---->
# group of organisms known by one particular common name-->
# P31---->
# Wikidata metaclass-->
# P31---->
# second-order metaclass-->
# P31---->
# third-order metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P31---->
# second-order metaclass-->
# P31---->
# third-order metaclass-->
#
#
# INTERSECCION EN fixed-order metaclass A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P1303---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
#
#
# En C2 la interseccion está a distancia 4
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
#
#
# INTERSECCION EN variable-order metaclass A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P31---->
# human-->
# P279---->
# natural person-->
# P31---->
# concept-->
# P31---->
# variable-order metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
# P31---->
# variable-order metaclass-->
#
#
# INTERSECCION EN (meta)class A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# Hans Zimmer-->
# P31---->
# human-->
# P279---->
# natural person-->
# P31---->
# concept-->
# P31---->
# variable-order metaclass-->
# P279---->
# (meta)class-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
# P279---->
# (meta)class-->
#
#
# INTERSECCION EN Wikidata metaclass A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P31---->
# human-->
# P31---->
# group of organisms known by one particular common name-->
# P31---->
# Wikidata metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P31---->
# first-order metaclass-->
# P279---->
# fixed-order metaclass-->
# P279---->
# Wikidata metaclass-->
#
#
# INTERSECCION EN class A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P1303---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
#
#
# En C2 la interseccion está a distancia 3
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
#
#
# INTERSECCION EN metaclass A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P136---->
# soundtrack-->
# P31---->
# music term-->
# P31---->
# metaclass-->
#
#
# En C2 la interseccion está a distancia 4
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P31---->
# metaclass-->
#
#
# INTERSECCION EN concept A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P31---->
# human-->
# P279---->
# natural person-->
# P31---->
# concept-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P31---->
# metaclass-->
# P31---->
# concept-->
#
#
# INTERSECCION EN formal ontology concept A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P136---->
# soundtrack-->
# P31---->
# music term-->
# P31---->
# metaclass-->
# P31---->
# formal ontology concept-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P31---->
# metaclass-->
# P31---->
# formal ontology concept-->
#
#
# INTERSECCION EN philosophical concept A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# Hans Zimmer-->
# P1303---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P31---->
# philosophical concept-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P31---->
# philosophical concept-->
#
#
# INTERSECCION EN abstract object A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P31---->
# human-->
# P279---->
# natural person-->
# P31---->
# concept-->
# P279---->
# abstract object-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P279---->
# abstract object-->
#
#
# INTERSECCION EN member of class (philosophy) A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# Hans Zimmer-->
# P1303---->
# keyboard instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P527---->
# member of class (philosophy)-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P31---->
# class of instruments-->
# P279---->
# class-->
# P279---->
# class-->
# P527---->
# member of class (philosophy)-->
#
#
# INTERSECCION EN electrophone A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P1303---->
# synthesizer-->
# P279---->
# electronic musical instrument-->
# P279---->
# electrophone-->
#
#
# En C2 la interseccion está a distancia 2
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
#
#
# INTERSECCION EN musical instrument A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
#
#
# En C2 la interseccion está a distancia 3
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# musical instrument-->
#
#
# INTERSECCION EN sound generator A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P279---->
# sound generator-->
#
#
# En C2 la interseccion está a distancia 4
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# musical instrument-->
# P279---->
# sound generator-->
#
#
# INTERSECCION EN device A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P279---->
# sound generator-->
# P279---->
# device-->
#
#
# En C2 la interseccion está a distancia 3
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electronic instrument-->
# P279---->
# device-->
#
#
# INTERSECCION EN tool A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
#
#
# En C2 la interseccion está a distancia 4
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
#
#
# INTERSECCION EN equipment A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# equipment-->
#
#
# En C2 la interseccion está a distancia 4
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electronic instrument-->
# P279---->
# device-->
# P279---->
# equipment-->
#
#
# INTERSECCION EN converter A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# converter-->
#
#
# INTERSECCION EN product A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# product-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# product-->
#
#
# INTERSECCION EN musical instrument part A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P527---->
# musical instrument part-->
#
#
# En C2 la interseccion está a distancia 4
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# musical instrument-->
# P527---->
# musical instrument part-->
#
#
# INTERSECCION EN work A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P31---->
# work-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P31---->
# work-->
#
#
# INTERSECCION EN part of A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P279---->
# part of-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# musical instrument-->
# P527---->
# musical instrument part-->
# P279---->
# part of-->
#
#
# INTERSECCION EN electrical apparatus A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Hans Zimmer-->
# P1303---->
# synthesizer-->
# P279---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# electrical apparatus-->
#
#
# En C2 la interseccion está a distancia 3
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# electrical apparatus-->
#
#
# INTERSECCION EN electrical load A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# Hans Zimmer-->
# P1303---->
# synthesizer-->
# P279---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# electrical apparatus-->
# P279---->
# electrical load-->
#
#
# En C2 la interseccion está a distancia 4
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electrophone-->
# P279---->
# electrical apparatus-->
# P279---->
# electrical load-->
#
#
# INTERSECCION EN electronic instrument A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Hans Zimmer-->
# P1303---->
# synthesizer-->
# P279---->
# electronic musical instrument-->
# P279---->
# electronic instrument-->
#
#
# En C2 la interseccion está a distancia 2
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electronic instrument-->
#
#
# INTERSECCION EN artificial physical object A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# Hans Zimmer-->
# P1303---->
# piano-->
# P31---->
# musical instrument-->
# P279---->
# tool-->
# P279---->
# equipment-->
# P279---->
# artificial physical object-->
#
#
# En C2 la interseccion está a distancia 5
# String synthesizer-->
# P31---->
# electronic musical instrument-->
# P279---->
# electronic instrument-->
# P279---->
# device-->
# P279---->
# equipment-->
# P279---->
# artificial physical object-->

# %% [markdown]
# - Pirates of the Caribbean: The Curse of the Black Pearl (Q46717),  The Lion King (Q36479)

# %%
comunes3 = getRelations(tree5,tree6)
len(comunes3)
# Out:
# 67

# %%
entidades3 = getEntidadesEnComun(comunes3)
print(entidades3)
# Out:
# ['film', 'visual artwork', 'work of art', 'creative work', 'intellectual work', 'item of collection or exhibition', 'physical object', 'goods', 'economic concept', 'economics term', 'perceptible object', 'artificial physical object', 'artificial entity', 'entity', 'audiovisual work', 'audiovisual', 'term', 'intangible good', 'series', 'group', 'class', 'metaclass', 'object', 'object of group', 'moving image', 'image', 'depiction', 'motion', 'physical process', 'change', 'linear motion', 'credit', 'acknowledgment', 'trailer', 'advertising', 'economic activity', 'information', 'service', 'film frame', 'photograph', 'motion picture credits', 'inscription', 'text', 'written work', 'communication medium', 'design element', 'title sequence', 'opening credits', 'credit name', 'film genre', 'art genre', 'genre', 'Wikidata metaclass', 'fiction', 'literary genre', 'drama', 'theatrical genre', 'video game theme', 'television genre', 'narrative', 'literature', 'second-order metaclass', 'class or metaclass of Wikidata ontology', 'literary work', 'art form', 'art', 'Language arts']

# %%
caminosToString(comunes3)
# Out:
# INTERSECCION EN film A DISTANCIA 3
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
#
#
# En C2 la interseccion está a distancia 1
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
#
#
# INTERSECCION EN visual artwork A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
#
#
# INTERSECCION EN work of art A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P279---->
# work of art-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
#
#
# INTERSECCION EN creative work A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
# P279---->
# creative work-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# creative work-->
#
#
# INTERSECCION EN intellectual work A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
# P279---->
# creative work-->
# P279---->
# intellectual work-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# creative work-->
# P279---->
# intellectual work-->
#
#
# INTERSECCION EN item of collection or exhibition A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P279---->
# work of art-->
# P279---->
# item of collection or exhibition-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# item of collection or exhibition-->
#
#
# INTERSECCION EN physical object A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
# P279---->
# physical object-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
# P279---->
# physical object-->
#
#
# INTERSECCION EN goods A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P279---->
# work of art-->
# P279---->
# goods-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# goods-->
#
#
# INTERSECCION EN economic concept A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P279---->
# work of art-->
# P279---->
# goods-->
# P31---->
# economic concept-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# goods-->
# P31---->
# economic concept-->
#
#
# INTERSECCION EN economics term A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P279---->
# work of art-->
# P279---->
# goods-->
# P31---->
# economics term-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# goods-->
# P31---->
# economics term-->
#
#
# INTERSECCION EN perceptible object A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P279---->
# work of art-->
# P279---->
# goods-->
# P279---->
# perceptible object-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# goods-->
# P279---->
# perceptible object-->
#
#
# INTERSECCION EN artificial physical object A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
#
#
# INTERSECCION EN artificial entity A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
# P279---->
# artificial entity-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
# P279---->
# artificial entity-->
#
#
# INTERSECCION EN entity A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P527---->
# entity-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P527---->
# entity-->
#
#
# INTERSECCION EN audiovisual work A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# audiovisual work-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
#
#
# INTERSECCION EN audiovisual A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# audiovisual-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# audiovisual-->
#
#
# INTERSECCION EN term A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# audiovisual-->
# P31---->
# term-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# audiovisual-->
# P31---->
# term-->
#
#
# INTERSECCION EN intangible good A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# intangible good-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# intangible good-->
#
#
# INTERSECCION EN series A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# series-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# series-->
#
#
# INTERSECCION EN group A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
#
#
# INTERSECCION EN class A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P136---->
# children's film-->
# P279---->
# children's fiction-->
# P31---->
# genre-->
# P279---->
# class-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P31---->
# class-->
#
#
# INTERSECCION EN metaclass A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# children's film-->
# P279---->
# children's fiction-->
# P31---->
# genre-->
# P31---->
# Wikidata metaclass-->
# P279---->
# metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P31---->
# class-->
# P31---->
# metaclass-->
#
#
# INTERSECCION EN object A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P279---->
# object-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P279---->
# object-->
#
#
# INTERSECCION EN object of group A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P527---->
# object of group-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P527---->
# object of group-->
#
#
# INTERSECCION EN moving image A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# moving image-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# moving image-->
#
#
# INTERSECCION EN image A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# image-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# image-->
#
#
# INTERSECCION EN depiction A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# image-->
# P279---->
# depiction-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# image-->
# P279---->
# depiction-->
#
#
# INTERSECCION EN motion A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
#
#
# INTERSECCION EN physical process A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P279---->
# physical process-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P279---->
# physical process-->
#
#
# INTERSECCION EN change A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P279---->
# change-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P279---->
# change-->
#
#
# INTERSECCION EN linear motion A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P527---->
# linear motion-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P527---->
# linear motion-->
#
#
# INTERSECCION EN credit A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# credit-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# credit-->
#
#
# INTERSECCION EN acknowledgment A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# credit-->
# P279---->
# credit-->
# P279---->
# acknowledgment-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# credit-->
# P279---->
# credit-->
# P279---->
# acknowledgment-->
#
#
# INTERSECCION EN trailer A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# trailer-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# trailer-->
#
#
# INTERSECCION EN advertising A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
#
#
# INTERSECCION EN economic activity A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P31---->
# economic activity-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P31---->
# economic activity-->
#
#
# INTERSECCION EN information A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P279---->
# information-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P279---->
# information-->
#
#
# INTERSECCION EN service A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P279---->
# service-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P279---->
# service-->
#
#
# INTERSECCION EN film frame A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# film frame-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# film frame-->
#
#
# INTERSECCION EN photograph A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# film frame-->
# P279---->
# photograph-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# film frame-->
# P279---->
# photograph-->
#
#
# INTERSECCION EN motion picture credits A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
#
#
# INTERSECCION EN inscription A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
#
#
# INTERSECCION EN text A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# text-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# text-->
#
#
# INTERSECCION EN written work A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# written work-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# written work-->
#
#
# INTERSECCION EN communication medium A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# communication medium-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# communication medium-->
#
#
# INTERSECCION EN design element A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# design element-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# design element-->
#
#
# INTERSECCION EN title sequence A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# title sequence-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# title sequence-->
#
#
# INTERSECCION EN opening credits A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# title sequence-->
# P527---->
# opening credits-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# title sequence-->
# P527---->
# opening credits-->
#
#
# INTERSECCION EN credit name A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P31---->
# animated film-->
# P279---->
# film-->
# P527---->
# title sequence-->
# P527---->
# opening credits-->
# P527---->
# credit name-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P31---->
# film-->
# P527---->
# title sequence-->
# P527---->
# opening credits-->
# P527---->
# credit name-->
#
#
# INTERSECCION EN film genre A DISTANCIA 4
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# The Lion King-->
# P31---->
# animated film-->
# P31---->
# film genre-->
#
#
# En C2 la interseccion está a distancia 2
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# fantasy film-->
# P31---->
# film genre-->
#
#
# INTERSECCION EN art genre A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P31---->
# animated film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# fantasy film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
#
#
# INTERSECCION EN genre A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P136---->
# children's film-->
# P279---->
# children's fiction-->
# P31---->
# genre-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# comedy film-->
# P279---->
# comedy-->
# P31---->
# genre-->
#
#
# INTERSECCION EN Wikidata metaclass A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P136---->
# children's film-->
# P279---->
# children's fiction-->
# P31---->
# genre-->
# P31---->
# Wikidata metaclass-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# comedy film-->
# P279---->
# comedy-->
# P31---->
# genre-->
# P31---->
# Wikidata metaclass-->
#
#
# INTERSECCION EN fiction A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P136---->
# children's film-->
# P279---->
# children's fiction-->
# P279---->
# fiction-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# fantasy film-->
# P279---->
# fiction film-->
# P279---->
# fiction-->
#
#
# INTERSECCION EN literary genre A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# literary genre-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# adventure film-->
# P279---->
# adventure fiction-->
# P31---->
# literary genre-->
#
#
# INTERSECCION EN drama A DISTANCIA 4
#
# ==============================================
#
# En C1 la interseccion está a distancia 1
# The Lion King-->
# P136---->
# drama-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# swashbuckler film-->
# P279---->
# costume drama-->
# P279---->
# drama-->
#
#
# INTERSECCION EN theatrical genre A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# theatrical genre-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# swashbuckler film-->
# P279---->
# costume drama-->
# P279---->
# drama-->
# P279---->
# drama-->
# P31---->
# theatrical genre-->
#
#
# INTERSECCION EN video game theme A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# video game theme-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# swashbuckler film-->
# P279---->
# costume drama-->
# P279---->
# drama-->
# P279---->
# drama-->
# P31---->
# video game theme-->
#
#
# INTERSECCION EN television genre A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# television genre-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# swashbuckler film-->
# P279---->
# costume drama-->
# P279---->
# historical period drama-->
# P31---->
# television genre-->
#
#
# INTERSECCION EN narrative A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P279---->
# narrative-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# swashbuckler film-->
# P279---->
# costume drama-->
# P279---->
# drama-->
# P279---->
# drama-->
# P279---->
# narrative-->
#
#
# INTERSECCION EN literature A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# literary genre-->
# P279---->
# literature-->
#
#
# En C2 la interseccion está a distancia 4
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# adventure film-->
# P279---->
# adventure fiction-->
# P31---->
# literary genre-->
# P279---->
# literature-->
#
#
# INTERSECCION EN second-order metaclass A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# children's film-->
# P279---->
# children's fiction-->
# P31---->
# genre-->
# P31---->
# Wikidata metaclass-->
# P31---->
# second-order metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# comedy film-->
# P279---->
# comedy-->
# P31---->
# genre-->
# P31---->
# Wikidata metaclass-->
# P31---->
# second-order metaclass-->
#
#
# INTERSECCION EN class or metaclass of Wikidata ontology A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# children's film-->
# P279---->
# children's fiction-->
# P31---->
# genre-->
# P31---->
# Wikidata metaclass-->
# P279---->
# class or metaclass of Wikidata ontology-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# comedy film-->
# P279---->
# comedy-->
# P31---->
# genre-->
# P31---->
# Wikidata metaclass-->
# P279---->
# class or metaclass of Wikidata ontology-->
#
#
# INTERSECCION EN literary work A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# literary genre-->
# P279---->
# literature-->
# P527---->
# literary work-->
#
#
# En C2 la interseccion está a distancia 3
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# comedy film-->
# P279---->
# comedy-->
# P279---->
# literary work-->
#
#
# INTERSECCION EN art form A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# literary genre-->
# P279---->
# literature-->
# P31---->
# art form-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# adventure film-->
# P279---->
# adventure fiction-->
# P31---->
# literary genre-->
# P279---->
# literature-->
# P31---->
# art form-->
#
#
# INTERSECCION EN art A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# literary genre-->
# P279---->
# literature-->
# P279---->
# art-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# adventure film-->
# P279---->
# adventure fiction-->
# P31---->
# literary genre-->
# P279---->
# literature-->
# P279---->
# art-->
#
#
# INTERSECCION EN Language arts A DISTANCIA 10
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# The Lion King-->
# P136---->
# drama-->
# P279---->
# drama-->
# P31---->
# literary genre-->
# P279---->
# literature-->
# P279---->
# Language arts-->
#
#
# En C2 la interseccion está a distancia 5
# Pirates of the Caribbean: The Curse of the Black Pearl-->
# P136---->
# adventure film-->
# P279---->
# adventure fiction-->
# P31---->
# literary genre-->
# P279---->
# literature-->
# P279---->
# Language arts-->

# %% [markdown]
# - Toy Story (Q171048), Iron Man (Q192724)

# %%
comunes4 = getRelations(tree7,tree8)
len(comunes4)
# Out:
# 56

# %%
entidades4 = getEntidadesEnComun(comunes4)
print(entidades4)
# Out:
# ['film', 'visual artwork', 'work of art', 'artificial physical object', 'audiovisual work', 'creative work', 'audiovisual', 'intangible good', 'series', 'group', 'moving image', 'image', 'motion', 'credit', 'trailer', 'advertising', 'film frame', 'photograph', 'motion picture credits', 'inscription', 'title sequence', 'opening credits', 'film genre', 'art genre', 'genre', 'Wikidata metaclass', 'class', 'intellectual work', 'item of collection or exhibition', 'goods', 'physical object', 'artificial entity', 'term', 'object', 'entity', 'object of group', 'depiction', 'physical process', 'change', 'linear motion', 'acknowledgment', 'economic activity', 'information', 'service', 'text', 'communication medium', 'written work', 'design element', 'credit name', 'speculative fiction', 'fiction', 'genre fiction', 'literary genre', 'belletristic literature', 'work', 'speculative fiction film']

# %%
caminosToString(comunes4)
# Out:
# INTERSECCION EN film A DISTANCIA 3
#
# ==============================================
#
# En C1 la interseccion está a distancia 1
# Iron Man-->
# P31---->
# film-->
#
#
# En C2 la interseccion está a distancia 2
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
#
#
# INTERSECCION EN visual artwork A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P279---->
# visual artwork-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
#
#
# INTERSECCION EN work of art A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
#
#
# INTERSECCION EN artificial physical object A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
#
#
# INTERSECCION EN audiovisual work A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# audiovisual work-->
#
#
# INTERSECCION EN creative work A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# creative work-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
# P279---->
# creative work-->
#
#
# INTERSECCION EN audiovisual A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# audiovisual-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# audiovisual-->
#
#
# INTERSECCION EN intangible good A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# intangible good-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# intangible good-->
#
#
# INTERSECCION EN series A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P279---->
# series-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# series-->
#
#
# INTERSECCION EN group A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
#
#
# INTERSECCION EN moving image A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P279---->
# moving image-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# moving image-->
#
#
# INTERSECCION EN image A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# image-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# image-->
#
#
# INTERSECCION EN motion A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
#
#
# INTERSECCION EN credit A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P527---->
# credit-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# credit-->
#
#
# INTERSECCION EN trailer A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P527---->
# trailer-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# trailer-->
#
#
# INTERSECCION EN advertising A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
#
#
# INTERSECCION EN film frame A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P527---->
# film frame-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# film frame-->
#
#
# INTERSECCION EN photograph A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P527---->
# film frame-->
# P279---->
# photograph-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# film frame-->
# P279---->
# photograph-->
#
#
# INTERSECCION EN motion picture credits A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
#
#
# INTERSECCION EN inscription A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
#
#
# INTERSECCION EN title sequence A DISTANCIA 5
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P31---->
# film-->
# P527---->
# title sequence-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# title sequence-->
#
#
# INTERSECCION EN opening credits A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P31---->
# film-->
# P527---->
# title sequence-->
# P527---->
# opening credits-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# title sequence-->
# P527---->
# opening credits-->
#
#
# INTERSECCION EN film genre A DISTANCIA 4
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P136---->
# action film-->
# P31---->
# film genre-->
#
#
# En C2 la interseccion está a distancia 2
# Toy Story-->
# P136---->
# buddy film-->
# P31---->
# film genre-->
#
#
# INTERSECCION EN art genre A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P136---->
# action film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# buddy film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
#
#
# INTERSECCION EN genre A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P136---->
# action film-->
# P279---->
# action fiction-->
# P31---->
# genre-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# buddy film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
# P279---->
# genre-->
#
#
# INTERSECCION EN Wikidata metaclass A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P136---->
# action film-->
# P279---->
# action fiction-->
# P31---->
# genre-->
# P31---->
# Wikidata metaclass-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
# P279---->
# genre-->
# P31---->
# Wikidata metaclass-->
#
#
# INTERSECCION EN class A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P31---->
# class-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
# P279---->
# genre-->
# P279---->
# class-->
#
#
# INTERSECCION EN intellectual work A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# creative work-->
# P279---->
# intellectual work-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P31---->
# film genre-->
# P279---->
# art genre-->
# P279---->
# creative work-->
# P279---->
# intellectual work-->
#
#
# INTERSECCION EN item of collection or exhibition A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# item of collection or exhibition-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# item of collection or exhibition-->
#
#
# INTERSECCION EN goods A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# goods-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# work of art-->
# P279---->
# goods-->
#
#
# INTERSECCION EN physical object A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
# P279---->
# physical object-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
# P279---->
# physical object-->
#
#
# INTERSECCION EN artificial entity A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
# P279---->
# artificial entity-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# visual artwork-->
# P279---->
# artificial physical object-->
# P279---->
# artificial entity-->
#
#
# INTERSECCION EN term A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# audiovisual-->
# P31---->
# term-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# audiovisual-->
# P31---->
# term-->
#
#
# INTERSECCION EN object A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P279---->
# object-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P279---->
# object-->
#
#
# INTERSECCION EN entity A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P527---->
# entity-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P527---->
# entity-->
#
#
# INTERSECCION EN object of group A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P527---->
# object of group-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# series-->
# P279---->
# group-->
# P527---->
# object of group-->
#
#
# INTERSECCION EN depiction A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# image-->
# P279---->
# depiction-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# image-->
# P279---->
# depiction-->
#
#
# INTERSECCION EN physical process A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P279---->
# physical process-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P279---->
# physical process-->
#
#
# INTERSECCION EN change A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P279---->
# change-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P279---->
# change-->
#
#
# INTERSECCION EN linear motion A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P527---->
# linear motion-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P279---->
# moving image-->
# P279---->
# motion-->
# P527---->
# linear motion-->
#
#
# INTERSECCION EN acknowledgment A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# credit-->
# P279---->
# credit-->
# P279---->
# acknowledgment-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# credit-->
# P279---->
# credit-->
# P279---->
# acknowledgment-->
#
#
# INTERSECCION EN economic activity A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P31---->
# economic activity-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P31---->
# economic activity-->
#
#
# INTERSECCION EN information A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P279---->
# information-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P279---->
# information-->
#
#
# INTERSECCION EN service A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P279---->
# service-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# trailer-->
# P279---->
# advertising-->
# P279---->
# service-->
#
#
# INTERSECCION EN text A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# text-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# text-->
#
#
# INTERSECCION EN communication medium A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# communication medium-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# communication medium-->
#
#
# INTERSECCION EN written work A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# written work-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# written work-->
#
#
# INTERSECCION EN design element A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# design element-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# motion picture credits-->
# P279---->
# inscription-->
# P279---->
# design element-->
#
#
# INTERSECCION EN credit name A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P31---->
# film-->
# P527---->
# title sequence-->
# P527---->
# opening credits-->
# P527---->
# credit name-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# buddy film-->
# P279---->
# film-->
# P527---->
# title sequence-->
# P527---->
# opening credits-->
# P527---->
# credit name-->
#
#
# INTERSECCION EN speculative fiction A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P136---->
# science fiction film-->
# P279---->
# science fiction-->
# P279---->
# speculative fiction-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# fantasy film-->
# P279---->
# fantasy-->
# P279---->
# speculative fiction-->
#
#
# INTERSECCION EN fiction A DISTANCIA 6
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P136---->
# action film-->
# P279---->
# action fiction-->
# P279---->
# fiction-->
#
#
# En C2 la interseccion está a distancia 3
# Toy Story-->
# P136---->
# fantasy film-->
# P279---->
# fiction film-->
# P279---->
# fiction-->
#
#
# INTERSECCION EN genre fiction A DISTANCIA 7
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P136---->
# action film-->
# P279---->
# action fiction-->
# P279---->
# genre fiction-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# fantasy film-->
# P279---->
# fantasy-->
# P279---->
# speculative fiction-->
# P279---->
# genre fiction-->
#
#
# INTERSECCION EN literary genre A DISTANCIA 8
#
# ==============================================
#
# En C1 la interseccion está a distancia 3
# Iron Man-->
# P136---->
# adventure film-->
# P279---->
# adventure fiction-->
# P31---->
# literary genre-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# fantasy film-->
# P279---->
# fantasy-->
# P279---->
# speculative fiction-->
# P279---->
# genre fiction-->
# P31---->
# literary genre-->
#
#
# INTERSECCION EN belletristic literature A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 4
# Iron Man-->
# P136---->
# action film-->
# P279---->
# action fiction-->
# P279---->
# genre fiction-->
# P279---->
# belletristic literature-->
#
#
# En C2 la interseccion está a distancia 5
# Toy Story-->
# P136---->
# fantasy film-->
# P279---->
# fantasy-->
# P279---->
# speculative fiction-->
# P279---->
# genre fiction-->
# P279---->
# belletristic literature-->
#
#
# INTERSECCION EN work A DISTANCIA 9
#
# ==============================================
#
# En C1 la interseccion está a distancia 5
# Iron Man-->
# P31---->
# film-->
# P279---->
# audiovisual work-->
# P279---->
# creative work-->
# P279---->
# intellectual work-->
# P279---->
# work-->
#
#
# En C2 la interseccion está a distancia 4
# Toy Story-->
# P136---->
# fantasy film-->
# P279---->
# fiction film-->
# P279---->
# recreative work-->
# P279---->
# work-->
#
#
# INTERSECCION EN speculative fiction film A DISTANCIA 4
#
# ==============================================
#
# En C1 la interseccion está a distancia 2
# Iron Man-->
# P136---->
# science fiction film-->
# P279---->
# speculative fiction film-->
#
#
# En C2 la interseccion está a distancia 2
# Toy Story-->
# P136---->
# fantasy film-->
# P279---->
# speculative fiction film-->

# %% [markdown]
# Al estudiar las relaciones entre las películas podemos ver que tienen más entidades en común y algo más concretas, es decir, que engloban a menos entidades demasiado genericas.
# En estos casos obtenemos entidades que engloban el arte basicamente, mientras que con las que no eran sobre películas obteniamos clases que podrían englobar tanto un instrumento como un animal.
